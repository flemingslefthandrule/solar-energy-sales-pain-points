# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('solar_panel_data.csv')
print(data.head())
print(data.describe())
X = data[["MaterialTechnology"]]
Y = data["GeographicLocation"]
# Out:
#   SolarPanelModel  Efficiency MaterialTechnology  InstallationCost  \
# 0          PanelB          15          Thin-Film              2800
# 1          PanelB          20    Monocrystalline              3200
# 2          PanelA          15          Thin-Film              2800
# 3          PanelB          20    Monocrystalline              2500
# 4          PanelA          20    Polycrystalline              2500
#
#    InverterCost MountingRackingSystem  GovernmentIncentive  \
# 0           900              Tracking                 1200
# 1           800                 Fixed                  800
# 2           800                 Fixed                 1000
# 3           900                 Fixed                 1000
# 4          1200                 Fixed                 1200
#
#         GeographicLocation  LocalRegulationsCost  Warranty FinancingOption
# 0      HighSolarIrradiance                   700        25           Lease
# ...

# %%
plt.scatter(X['MaterialTechnology'], Y, color='b')
plt.xlabel('Material Technology')  
plt.ylabel('Geographic Location') 
plt.show()
