# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('solar_panel_data.csv')
print(data.head())
print(data.describe())
X = data[["InstallationCost"]]
Y = data["GovernmentIncentive"]
Y_ = data["Efficiency"]
# Out:
#    SolarPanelModel  Efficiency  MaterialTechnology  InstallationCost  \
# 0                9          20                   1              2800
# 1                8          20                   2              2500
# 2                8          18                   3              2800
# 3                8          15                   2              3200
# 4                7          15                   1              2800
#
#    InverterCost  MountingRackingSystem  GovernmentIncentive  \
# 0           800                      1                  800
# 1           900                      1                 1200
# 2           900                      0                 1000
# 3          1200                      1                 1000
# 4           900                      1                 1200
#
#    GeographicLocation  LocalRegulationsCost  Warranty  FinancingOption
# 0                 1.0                   600        25                4
# ...

# %%
#LINEAR REGRESSION
mdl = LinearRegression()
mdl.fit(X, Y)
pred = mdl.predict([[6.575]])
print("Predicted value (LR): ",pred[0])
print("Accuracy (LR): ",mdl.score(X[:100], Y[:100])*100)

plt.scatter(X['InstallationCost'], Y, color='b')
plt.plot(X['InstallationCost'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('Installation Cost')  
plt.ylabel('Government Incentive') 
plt.show()
# Out:
# Predicted value (LR):  1131.5323344638273
# Accuracy (LR):  0.8004002297285151
# /home/sam/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#MULTIPLE LINEAR REGRESSION
X = data[["InstallationCost","InverterCost"]]
mdl = LinearRegression()
mdl.fit(X, Y)
pred = mdl.predict([[6.575, 4.09]])
print("Predicted value (MLR): ",pred[0])
print("Accuracy (MLR): ",mdl.score(X[:100], Y[:100])*100)

plt.scatter(X['InstallationCost'], Y, color='b')
plt.plot(X['InstallationCost'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('installation cost')  
plt.ylabel('buy rate') 
plt.show()
# Out:
# /home/sam/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Predicted value (MLR):  1106.1380351047815
# Accuracy (MLR):  1.228869417900369
